# %% [markdown]
# # Playing with OAI-PMH
#
# Some possible exercises with OAI-PMH

# %%
import requests
import xml.etree.ElementTree as ET

# %% [markdown]
# This notebook uses the Renaissance Center set from Wayne State Digital Collections.
# See https://cdm17409.contentdm.oclc.org/digital/collection/rencen/search

# %%
endpoint = 'https://cdm17409.contentdm.oclc.org/oai/oai.php'

# %% [markdown]
# Use the initial, basic OAI verbs:
#
# * **Identify** - provide information about the repository
# * **ListSets** - list the sets of content that are available in the repository
# * **ListRecords** - provide metadata for all of the records in a given format from a given set
#
# ## Identify

# %%
identify = requests.get(endpoint, params={'verb':'Identify'})

# %%
identify.status_code
# Out:
# 200

# %%
identify.text[:200]
# Out:
# '<?xml version="1.0" encoding="UTF-8"?><OAI-PMH xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openarchives.org/OAI/2.'

# %%
root = ET.fromstring(identify.text)
#root = tree.getroot() note that in the above, no need for .getroot() when parsing from a string

# %%
type(root)
# Out:
# xml.etree.ElementTree.Element

# %%
root.tag
# Out:
# '{http://www.openarchives.org/OAI/2.0/}OAI-PMH'

# %%
ns = {
    'oai': 'http://www.openarchives.org/OAI/2.0/'
}

# %%
for element in root.iter():
    print(element.tag)
# Out:
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH
# {http://www.openarchives.org/OAI/2.0/}responseDate
# {http://www.openarchives.org/OAI/2.0/}request
# {http://www.openarchives.org/OAI/2.0/}Identify
# {http://www.openarchives.org/OAI/2.0/}repositoryName
# {http://www.openarchives.org/OAI/2.0/}baseURL
# {http://www.openarchives.org/OAI/2.0/}protocolVersion
# {http://www.openarchives.org/OAI/2.0/}adminEmail
# {http://www.openarchives.org/OAI/2.0/}earliestDatestamp
# {http://www.openarchives.org/OAI/2.0/}deletedRecord
# {http://www.openarchives.org/OAI/2.0/}granularity

# %%
Identity = root.find('oai:Identify', namespaces=ns)

# %%
Identity.tag
# Out:
# '{http://www.openarchives.org/OAI/2.0/}Identify'

# %%
for element in Identity:
    print(element.tag, element.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}repositoryName CONTENTdm Server Repository
# {http://www.openarchives.org/OAI/2.0/}baseURL http://cdm17409.contentdm.oclc.org/oai/oai.php
# {http://www.openarchives.org/OAI/2.0/}protocolVersion 2.0
# {http://www.openarchives.org/OAI/2.0/}adminEmail digitalcollections@wayne.edu
# {http://www.openarchives.org/OAI/2.0/}earliestDatestamp 2022-05-04
# {http://www.openarchives.org/OAI/2.0/}deletedRecord transient
# {http://www.openarchives.org/OAI/2.0/}granularity YYYY-MM-DD

# %% [markdown]
# dump all that into a dictionary!

# %%
Repo_Identity_Info = dict()

for element in Identity:
    Repo_Identity_Info[element.tag.split('}')[1]] = element.text

# %%
Repo_Identity_Info
# Out:
# {'repositoryName': 'CONTENTdm Server Repository',
#  'baseURL': 'http://cdm17409.contentdm.oclc.org/oai/oai.php',
#  'protocolVersion': '2.0',
#  'adminEmail': 'digitalcollections@wayne.edu',
#  'earliestDatestamp': '2022-05-04',
#  'deletedRecord': 'transient',
#  'granularity': 'YYYY-MM-DD'}

# %% [markdown]
# Now, any time you need to refer to the basic information about this Repository,
# you can refer back to the `Repo_Identity_Info`.

# %% [markdown]
# ## ListSets
#
# Now, list the sets...

# %%
sets = requests.get(Repo_Identity_Info['baseURL'], params={'verb': 'ListSets'})

# %%
sets.status_code
# Out:
# 200

# %%
sets.text[:100]
# Out:
# '<?xml version="1.0" encoding="UTF-8"?><OAI-PMH xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xs'

# %%
Repo_Sets = ET.fromstring(sets.text)

# %%
for element in Repo_Sets:
    print(element.tag)
# Out:
# {http://www.openarchives.org/OAI/2.0/}responseDate
# {http://www.openarchives.org/OAI/2.0/}request
# {http://www.openarchives.org/OAI/2.0/}ListSets

# %%
SetList = Repo_Sets.find('oai:ListSets', namespaces=ns)

# %% [markdown]
# Now, we know that for each set, there is an element called `setSpec`,
# which is a unique string to identify the set, and a `setName`, which
# is a human readable namestring. Let's pull those into a JSON file:

# %%
len(SetList)
# Out:
# 26

# %% [markdown]
# It looks like there's 26 sets!

# %%
for set in SetList:
    setID = set.find('oai:setSpec', namespaces=ns).text
    name  = set.find('oai:setName', namespaces=ns).text
    print(setID, ':', name)
# Out:
# vmc : Virtual Motor City
# rencen : Building the Detroit Renaissance Center
# auto-industry : Changing Face of the Auto Industry
# cooper : Dennis Glen Cooper Collection
# det-focus : Detroit Focus Quarterly
# det-sun-jrnl : Detroit Sunday Journal
# digital-dress : Digital Dress Collection
# eloise-ramsey : Eloise Ramsey Collection of Literature for Young People
# first-heart : First U.S. Human-to-Human Heart Transplant
# nightingale : Florence Nightingale Collection
# herman-miller : Herman Miller Consortium Collection
# lgbt-detroit : LGBT Detroit Records
# lincoln-ltrs : The Lincoln Letters
# made-in-mich : Made in Michigan Writers Series
# mot-programs : Michigan Opera Theatre Archive Programs Collection
# mot-images : Michigan Opera Theatre Performance Images
# cass-gilbert : Selected Cass Gilbert Architectural Drawings of the Detroit Public Library
# shakespeare : Shakespeare Lear Project
# toni-swanger : Toni Swanger Papers
# ufw-image : United Farm Workers Image Gallery
# van-riper : Van Riper Family Correspondence
# wayne-open : Wayne Open Book Collection
# wsu-buildings : Wayne State University Buildings Collection
# wsu-life : Wayne State University Student Life Collection
# wpa-music : WPA Music Manuscripts
# dte-aerial : DTE Aerial

# %%
import json

# %%
setCount = 0
setList = list()

for set in SetList:
    setID = set.find('oai:setSpec', namespaces=ns).text
    setInfo = {
        'number': setCount,
        'setID' : set.find('oai:setSpec', namespaces=ns).text,
        'name'  : set.find('oai:setName', namespaces=ns).text
    }
    setList.append(setInfo)
    print(f'added {setID}')
    setCount += 1

with open('setList.json', 'a', encoding='utf-8') as f:
    json.dump(setList, f, indent=2)
# Out:
# added vmc
# added rencen
# added auto-industry
# added cooper
# added det-focus
# added det-sun-jrnl
# added digital-dress
# added eloise-ramsey
# added first-heart
# added nightingale
# added herman-miller
# added lgbt-detroit
# added lincoln-ltrs
# added made-in-mich
# added mot-programs
# added mot-images
# added cass-gilbert
# added shakespeare
# added toni-swanger
# added ufw-image
# added van-riper
# added wayne-open
# added wsu-buildings
# added wsu-life
# added wpa-music
# added dte-aerial

# %% [markdown]
# Now, you can load set information from the file `setList.json`.

# %%
saved_setList = json.load(open('setList.json'))

type(saved_setList)

for item in saved_setList:
    print(item['setID'])
# Out:
# vmc
# rencen
# auto-industry
# cooper
# det-focus
# det-sun-jrnl
# digital-dress
# eloise-ramsey
# first-heart
# nightingale
# herman-miller
# lgbt-detroit
# lincoln-ltrs
# made-in-mich
# mot-programs
# mot-images
# cass-gilbert
# shakespeare
# toni-swanger
# ufw-image
# van-riper
# wayne-open
# wsu-buildings
# wsu-life
# wpa-music
# dte-aerial

# %% [markdown]
# ## ListRecords
#
# Finally, use the verb `ListRecords` to view information for each of the items in a given set.
# This one can be slightly more complicated since some repositories have hundreds of items
# in a given set, and typically the OAI-PMH endpoint will provide information in paginated
# results. To work through the individual pages of the response, you will need to look
# for the `resumptionToken` element, which can be provided back to the requests URL
# as a parameter to receive the next page of results.
#
# This is also more complex since these records will typically be shared in DublinCore
# fields, so an additional namespace record must be added.

# %%
Records = requests.get(Repo_Identity_Info['baseURL'], 
                       params={
                           'verb': 'ListRecords', 
                           'set': 'rencen', 
                           'metadataPrefix': 'oai_dc'
                           })

# %%
Records.url
# Out:
# 'http://cdm17409.contentdm.oclc.org/oai/oai.php?verb=ListRecords&set=rencen&metadataPrefix=oai_dc'

# %%
Records.status_code
# Out:
# 200

# %%
Records.text[:100]
# Out:
# '<?xml version="1.0" encoding="UTF-8"?><OAI-PMH xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xs'

# %%
recordRoot = ET.fromstring(Records.text)

for element in recordRoot:
    print(element.tag)
# Out:
# {http://www.openarchives.org/OAI/2.0/}responseDate
# {http://www.openarchives.org/OAI/2.0/}request
# {http://www.openarchives.org/OAI/2.0/}ListRecords

# %%
records = recordRoot.find('oai:ListRecords', ns)

# %%
len(records)
# Out:
# 201

# %% [markdown]
# Take a look at the first item in the list of records to get an idea of the structure:

# %%
item = ET.tostring(records[0], default_namespace='http://www.openarchives.org/OAI/2.0/', xml_declaration=True, encoding='utf-8').decode('utf-8')
print(item)
# Out:
# <?xml version='1.0' encoding='utf-8'?>
# <record xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:ns1="http://www.openarchives.org/OAI/2.0/oai_dc/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"><header><identifier>oai:cdm17409.contentdm.oclc.org:rencen/0</identifier><datestamp>2023-03-20</datestamp><setSpec>rencen</setSpec></header>
# <metadata>
# <ns1:dc xsi:schemaLocation="http://www.openarchives.org/OAI/2.0/oai_dc/ http://www.openarchives.org/OAI/2.0/oai_dc.xsd">
# <dc:title>View of ongoing construction of the Renaissance Center towers</dc:title>
# <dc:description>Image of the building progress on two of the four towers of the Renaissance Center.  Construction equipment is clearing visible.</dc:description>
# <dc:identifier>rencen_05b</dc:identifier>
# <dc:date>1973</dc:date>
# <dc:type>still image</dc:type>
# <dc:format>photographs</dc:format>
# <dc:coverage>Detroit, Michigan</dc:coverage>
# <dc:coverage>1970s</dc:coverage>
# <dc:relation>Building the Detroit Renaissance Center</dc:relation>
# <dc:rights>Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder.</dc:rights>
# <dc:date>1973</dc:date>
# <dc:identifier>http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/0</dc:identifier></ns1:dc>
# </metadata>
# </record>

# %% [markdown]
# Write out for inspection:

# %%
print(str(item))
# Out:
# <?xml version='1.0' encoding='utf-8'?>
# <record xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:ns1="http://www.openarchives.org/OAI/2.0/oai_dc/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"><header><identifier>oai:cdm17409.contentdm.oclc.org:rencen/0</identifier><datestamp>2023-03-20</datestamp><setSpec>rencen</setSpec></header>
# <metadata>
# <ns1:dc xsi:schemaLocation="http://www.openarchives.org/OAI/2.0/oai_dc/ http://www.openarchives.org/OAI/2.0/oai_dc.xsd">
# <dc:title>View of ongoing construction of the Renaissance Center towers</dc:title>
# <dc:description>Image of the building progress on two of the four towers of the Renaissance Center.  Construction equipment is clearing visible.</dc:description>
# <dc:identifier>rencen_05b</dc:identifier>
# <dc:date>1973</dc:date>
# <dc:type>still image</dc:type>
# <dc:format>photographs</dc:format>
# <dc:coverage>Detroit, Michigan</dc:coverage>
# <dc:coverage>1970s</dc:coverage>
# <dc:relation>Building the Detroit Renaissance Center</dc:relation>
# <dc:rights>Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder.</dc:rights>
# <dc:date>1973</dc:date>
# <dc:identifier>http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/0</dc:identifier></ns1:dc>
# </metadata>
# </record>

# %% [markdown]
# One thing that the individual record suggests is that we will need a more complex namespace dicionary. Let's add in the new namespaces:

# %%
ns = {
    'oai'   : 'http://www.openarchives.org/OAI/2.0/',
    'dc'    : 'http://purl.org/dc/elements/1.1/',
    'oai_dc': 'http://www.openarchives.org/OAI/2.0/oai_dc/'
}

# %% [markdown]
# This would also be a good chance to practice your XPath!
#
# Let's try: First, loop through the records, and find the titles and identifiers, then
# find all of the DublinCore metadata elements.

# %%
for elem in recordRoot.iter():
    print(elem.tag)
# Out:
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH
# {http://www.openarchives.org/OAI/2.0/}responseDate
# {http://www.openarchives.org/OAI/2.0/}request
# {http://www.openarchives.org/OAI/2.0/}ListRecords
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# ...
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}record
# {http://www.openarchives.org/OAI/2.0/}header
# {http://www.openarchives.org/OAI/2.0/}identifier
# {http://www.openarchives.org/OAI/2.0/}datestamp
# {http://www.openarchives.org/OAI/2.0/}setSpec
# {http://www.openarchives.org/OAI/2.0/}metadata
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}relation
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}identifier
# {http://www.openarchives.org/OAI/2.0/}resumptionToken

# %%
for title in recordRoot.iter('{http://purl.org/dc/elements/1.1/}title'):
    print(title)
# Out:
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa33002fe50>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa330037770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa330037db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa330038450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa330038a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa33003a130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa33003a770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa33003adb0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa33003e450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa33003ea90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa330040130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa330040770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa330040db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa330042450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa330042a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa330045130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa330045770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa330045db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa330047450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa330047a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e73130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e73770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e73db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e74450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e74a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e76130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e76770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e76db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e78450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e78a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e7b130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e7b770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e7bdb0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e7d450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e7da90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e80130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e80770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e80db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e82450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e82a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e83130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e83770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e83db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e86450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e86a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e88130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e88770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e88db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e8a450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e8aa90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e8c130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e8c770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e8cdb0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e8f450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e8fa90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e91130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e91770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e91db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e95450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e95a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e96130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e96770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e96db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e98450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e98a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e9a130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e9a770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e9adb0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e9c450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348e9ca90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348ea0130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348ea0770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348ea0db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348ea2450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348ea2a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348ea6130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348ea6770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348ea6db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348ea9450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348ea9a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348eac130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348eac770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348eacdb0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348ead450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348eada90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348eaf130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348eaf770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa348eafdb0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349340450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349340a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349343130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349343770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349343db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349347450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349347a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349349130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349349770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349349db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34934a450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34934aa90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34934e130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34934e770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34934edb0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349350450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349350a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349353130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349353770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349353db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349355450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349355a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349357130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349357770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349357db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349358450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349358a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34935b130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34935b770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34935bdb0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34935e450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34935ea90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349361130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349361770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349361db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349362450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349362a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349365130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349365770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349365db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349368450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349368a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34936c130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34936c770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34936cdb0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34936f450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34936fa90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349371130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349371770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349371db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349374450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349374a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349377130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349377770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349377db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349379450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349379a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34937a130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34937a770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34937adb0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34937d450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34937da90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349380130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349380770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349380db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349382450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349382a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349383130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349383770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349383db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349386450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349386a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349388130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349388770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349388db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34938c450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34938ca90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34938d130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34938d770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34938ddb0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349390450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349390a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349391130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349391770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349391db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349395450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349395a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349396130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349396770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349396db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349399450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa349399a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34939a130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34939a770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34939adb0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34939e450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa34939ea90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa3493a1130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa3493a1770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa3493a1db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa3493a3450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa3493a3a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa3493a5130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa3493a5770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa3493a5db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa3493a7450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa3493a7a90>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa3493a9130>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa3493a9770>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa3493a9db0>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa3493ad450>
# <Element '{http://purl.org/dc/elements/1.1/}title' at 0x7fa3493ada90>

# %%
ns
# Out:
# {'oai': 'http://www.openarchives.org/OAI/2.0/',
#  'dc': 'http://purl.org/dc/elements/1.1/',
#  'oai_dc': 'http://www.openarchives.org/OAI/2.0/oai_dc/'}

# %% [markdown]
# Use XPath to identify elements in the tree; the title, for example:

# %%
for record in records:
    title = record.find('oai:metadata/oai_dc:dc/dc:title', ns).text
    print(title)
# Out:
# View of ongoing construction of the Renaissance Center towers
# View of the ground floor atrium in the completed Renaissance Center.
# The Renaissance Center towers as viewed from Jefferson Avenue
# View of the atrium in the completed Renaissance Center.
# View of an unidentified building near the Renaissance Center construction site
# View of the Renaissance Center construction site with earth moving equipment
# View of unidentified buildings near the Renaissance Center construction site
# The Renaissance Center towers with derricks
# View of the future site of Hart Plaza and a drill rig, south of the Renaissance Center site
# View of support beams and construction equipment at the Renaissance Center building site
# View of construction workers preparing the building site of the Renaissance Center
# View of early stages of construction of the Renaissance Center complex of buildings
# View of the Lafayette Tool and Die parking lot near the Renaissance Center construction site
# View of Jefferson Avenue near the Renaissance Center construction site
# View of early progress on construction of the Renaissance Center
# View of the atrium in the Renaissance Center
# View of Jefferson Avenue northeast of the Renaissance Center construction site
# Future location of Hart Plaza near the Renaissance Center construction site
# View of Jefferson Avenue near the Renaissance Center construction site
# View of construction workers and equipment on the Renaissance Center site
# View of the completed Renaissance Center from the Detroit River
# View of the top of a Renaissance Center tower with visible construction equipment
# View of the base of the Renaissance Center during construction
# Upward view of progress on a Renaissance Center tower
# Ariel view of the Renaissance Center and the Detroit River
# View of Grand Trunk Railroad train cars in the vicinity of the Renaissance Center
# View of Ford Auditorium in the shadow of a Renaissance Center tower
# Future site of the Renaissance Center viewed from Canada
# View of earth moving equipment at the Renaissance Center site
# View of Renaissance Center tower construction and crane
# View of an unidentified building near the Renaissance Center construction site
# View of unidentified buildings near the Renaissance Center construction site
# View of unidentified buildings near the Renaissance Center construction site
# Ariel view of Ford Auditorium, directly south of the Renaissance Center building site
# View from the ground of the Renaissance Center construction progress
# Completed Renaissance Center viewed from Canada
# View of the upper portions of the Renaissance Center towers during construction
# View of an unidentified building near the Renaissance Center construction site
# Close-up view of ongoing construction of the Renaissance Center towers
# View of workers preparing the Renaissance Center construction site
# View of early progress at the Renaissance Center construction site
# View of unidentified buildings near the Renaissance Center construction site
# View of a Renaissance Center tower during construction next to Ford Auditorium
# View of the ongoing construction of the Renaissance Center Towers.
# View of unidentified buildings near the Renaissance Center construction site
# View of construction derricks on a Renaissance Center tower
# View of unidentified buildings near the Renaissance Center construction site
# View of upper section of a Renaissance Center tower
# View of the atrium in the completed Renaissance Center.
# View of a Renaissance Center center tower showing progress of construction
# Upper portion of the Renaissance Center towers during construction
# View from the ground of the northeast side of the Renaissance Center during construction
# View of the future location of Hart Plaza, near the Renaissance Center construction site
# View of a Renaissance Center tower and construction equipment
# View of workers and construction equipment at the site of the Renaissance Center
# View of a parking lot near Franklin and Chene Streets in the vicinity of the Renaissance Center building site
# View of an unidentified building near the Renaissance Center construction site
# View of an unidentified building near the Renaissance Center construction site
# View of the Renaissance Center from Jefferson Avenue
# View of unidentified buildings near the Renaissance Center construction site
# View of unidentified buildings in the area of the Renaissance Center
# View of a building on Woodbridge Street near the Renaissance Center construction site
# View of the progress made during construction of the Renaissance Center
# View of an unidentified building near the Renaissance Center construction site
# View of the Renaissance Center building site from the Detroit River
# View of an unidentified building near the Renaissance Center construction site
# View of the Renaissance Center site during early stages of construction
# Future site of Hart Plaza, built just south of the Renaissance Center building site
# View of unidentified buildings near the Renaissance Center construction site
# View of a derrick at the Renaissance Center construction site
# View of the Globe Trading Company building near the Renaissance Center construction site
# View of continuing progression the Renaissance Center structures
# View of the Renaissance Center during construction as seen from Jefferson Avenue
# The Renaissance Center construction site as seen from an employee parking area
# View of the progress of two Renaissance Center towers
# View of an unidentified building near the Renaissance Center construction site
# View of the Handleman Company building near the Renaissance Center
# View of construction equipment and workers at the Renaissance Center site
# View of construction equipment used at the Renaissance Center building site
# View of unidentified buildings near the Renaissance Center construction site
# View of an unidentified building near the Renaissance Center construction site
# The Renaissance Center construction site and Jefferson Avenue
# View of building at the corner of Rivard and Woodbridge Streets near the Renaissance Center construction site
# View of the Cemex-Medusa Cement Silo on Atwater Street situated northeast of the Renaissance Center building site
# View of Ford Auditorium and the site for Hart Plaza near the Renaissance Center
# View of the corner of Woodbridge Street and Orleans Street near the Renaissance Center constructions site
# Close-up of a construction derrick on the Renaissance Center building site
# The Renaissance Center and its towers during construction
# View of construction equipment at the building site of the Renaissance Center
# View of Ford Auditorium, as it stood next to the Renaissance Center construction site
# View of an unidentified building near the Renaissance Center construction site
# View of drill rig at the Renaissance Center construction site
# View of an unidentified building near the Renaissance Center construction site
# View of unidentified buildings near the Renaissance Center construction site
# The Renaissance Center construction site and the Ammex sign at the entrance to the Tunnel to Canada
# View of unidentified buildings in the area of the Renaissance Center
# View of unidentified buildings near the Renaissance Center construction site
# View of the top of the Renaissance Center towers during construction
# View of Jefferson Avenue just north of the Renaissance Center building site
# View of the Jefferson Chevrolet Automobile Dealership near the Renaissance Center building site
# View of unidentified buildings near the Renaissance Center construction site
# Upward view of the Renaissance Center towers with visible construction equipment
# The Renaissance Center during construction as seen from the northeast side
# View of an unidentified building near the Renaissance Center construction site
# View of progress of the Renaissance Center construction site
# View of construction equipment at the Renaissance Center building site
# View of a tower of the Renaissance Center with derricks on the top
# View of the top of the Renaissance Center towers during construction
# Ground level view of the construction of the Renaissance Center
# View of early stages of construction of the Renaissance Center
# Up-close view of construction equipment during building of the Renaissance Center
#  View of the Renaissance Center, during construction, from Jefferson Avenue
# View of a Renaissance Center tower as construction progresses
# View of an unidentified building near the Renaissance Center construction site
# View of unidentified buildings near the Renaissance Center construction site
# Close-up view of a Renaissance Center tower section of during construction
# View of unidentified buildings near the Renaissance Center construction site
# View of the base of a Renaissance Center tower during construction
# View of the construction site of the Renaissance Center, Jefferson Avenue, and the Tunnel to Canada grounds.
# View of derricks and scaffolding on the Renaissance Center during construction
# View of unidentified buildings near the Renaissance Center construction site
# View of unidentified buildings near the Renaissance Center construction site
# View of the Renaissance Center from the sky during construction
# View of the corner of Riopelle Street and Jefferson Avenue in the vicinity of the Renaissance Center construction site
# Upward view of the Renaissance Center towers during construction
# The Renaissance Center building site with heavy equipment and workers
# View of the Renaissance Center construction site
# View of the Renaissance Center construction site and Detroit skyline
# View of an unidentified building near the Renaissance Center construction site
# View of progress of construction of a Renaissance Center tower
# View of the Renaissance Center towers in early stages of construction
# View of an unidentified building near the Renaissance Center construction site
# Ariel view of the Renaissance Center construction site
# View of local billboard announcing Phase 1 of construction of the Renaissance Center
# View of the Renaissance Center site in early stages of construction
# View of unidentified buildings near the Renaissance Center construction site
# View of a tower as construction continues on the Renaissance Center
# View of an unidentified building near the Renaissance Center construction site
# View of an unidentified building near the Renaissance Center construction site
# View of Ford Auditorium, immediately south of the Renaissance Center building site
# View of unidentified buildings near the Renaissance Center construction site
# Upward view of the Renaissance Center from an employee parking area
# View of the John Kendall fireboat near Renaissance Center construction site
# Two of the Renaissance Center towers during early construction
# View of unidentified building near the Renaissance Center construction site
# View of the top portion of a Renaissance Center tower during construction
# Closeup view of construction progress on the Renaissance Center towers
# View of unidentified buildings in the area of the Renaissance Center building site
# View of an industrial building on Franklin Street near the Renaissance Center construction site
# View of an unidentified building near the Renaissance Center construction site
# View of the progress of construction on the Renaissance Center
# View of an unidentified building near the Renaissance Center construction site
# View of an unidentified building near the Renaissance Center construction site
# View of a drill rig at the Renaissance Center construction site
# View of an unidentified building near the Renaissance Center construction site
# View of an unidentified building near the Renaissance Center construction site
# View of unidentified buildings near the Renaissance Center construction site
# View of the completed Renaissance Center as seen from the Detroit River
# View of an unidentified building near the Renaissance Center construction site
# Progress on the construction of the Renaissance Center as seen from a distance
# View of an unidentified building near the Renaissance Center construction site
# View of the Ambassador Bridge, four miles south of the Renaissance Center, as seen from Windsor, Ontario, Canada.
# View of construction progress of a Renaissance Center tower
# View of an unidentified building near the Renaissance Center construction site
# The Renaissance Center Towers under construction
# View of the top of a Renaissance Center tower during construction
# View of a Grand Truck Railroad engine near the Renaissance Center
# The Renaissance Center towers with visible construction equipment
# Ford Auditorium as seen during construction of the Renaissance Center towers
# Future site of Hart Plaza and Ford Auditorium near the Renaissance Center site
# View of a portion of an atrium in the completed Renaissance Center.
# View of the northeast side of the Renaissance Center during construction
# The Renaissance Center during construction as seen from across Jefferson Avenue
# View of the base of a Renaissance Center tower during early construction
# View of an unidentified building near the Renaissance Center construction site
# Renaissance Center building site with construction equipment in use
# View of an architectural model or artist's rendering of the Renaissance Center complex
# View of an unidentified building near the Renaissance Center construction site
# The Renaissance Center seen from inside another building from a distance
# View of the railroad tracks north of the Renaissance Center building site
# View of unidentified buildings near the Renaissance Center construction site
# View of equipment used during the construction of the Renaissance Center
# Construction equipment on the Renaissance Center towers
# View of the area south of the Renaissance Center construction site
# View of the construction progress on a Renaissance Center tower
#  Closeup view of a Renaissance Center tower
# View of unidentified buildings near the Renaissance Center construction site
# View of the Renaissance Center construction site with drill rigs
# View of Randolph Street at the edge of the Renaissance Center construction site
# View of the Northern Engineering Works building near the Renaissance Center construction site
# Construction of the Renaissance Center towers
# View of the corner of Atwater and Orleans Streets near the Renaissance Center building site
# View of the Detroit River as seen near the construction site of the Renaissance Center
# View of a Renaissance Center tower focused on the upper area during construction
# View of an unidentified building near the Renaissance Center construction site
# The Renaissance Center during construction and a busy Jefferson Avenue
# View of the corner of Atwater and Chene Streets in the area of the Renaissance Center building site
# Upward view of a Renaissance Center tower as construction progressed
# View of the Ammex duty free shop sign adjacent to the Renaissance Center building site
# Artist's model of the completed Renaissance Center complex
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/jajohnst/Desktop/networked-services-labs-2023/xml-exploring-OAIPMH.ipynb Cell 55 line 2
#       <a href='vscode-notebook-cell:/Users/jajohnst/Desktop/networked-services-labs-2023/xml-exploring-OAIPMH.ipynb#Y106sZmlsZQ%3D%3D?line=0'>1</a> for record in records:
# ----> <a href='vscode-notebook-cell:/Users/jajohnst/Desktop/networked-services-labs-2023/xml-exploring-OAIPMH.ipynb#Y106sZmlsZQ%3D%3D?line=1'>2</a>     title = record.find('oai:metadata/oai_dc:dc/dc:title', ns).text
#       <a href='vscode-notebook-cell:/Users/jajohnst/Desktop/networked-services-labs-2023/xml-exploring-OAIPMH.ipynb#Y106sZmlsZQ%3D%3D?line=2'>3</a>     print(title)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# Build up a loop to look through all of the DublinCore elements in each record:

# %%
for record in records:
    id = record.find('oai:metadata/oai_dc:dc/dc:identifier', ns).text
    print('Item',id)
    for dc in record.iterfind('oai:metadata//dc:*', ns):
        print('  ',dc.text,dc.tag)
# Out:
# Item rencen_05b
#    View of ongoing construction of the Renaissance Center towers {http://purl.org/dc/elements/1.1/}title
#    Image of the building progress on two of the four towers of the Renaissance Center.  Construction equipment is clearing visible. {http://purl.org/dc/elements/1.1/}description
#    rencen_05b {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/0 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_03d
#    View of the ground floor atrium in the completed Renaissance Center. {http://purl.org/dc/elements/1.1/}title
#    Image of the atrium within the Renaissance Center, looking down from the second floor. Note the concrete supports and components that make up portions of this building. {http://purl.org/dc/elements/1.1/}description
#    rencen_03d {http://purl.org/dc/elements/1.1/}identifier
#    1977 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1977 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/1 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_09f
#    The Renaissance Center towers as viewed from Jefferson Avenue {http://purl.org/dc/elements/1.1/}title
#    Image of the partially built Renaissance Center towers during construction.  This photograph was taken from Jefferson Avenue and derricks and scaffolding are visible. {http://purl.org/dc/elements/1.1/}description
#    rencen_09f {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/2 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_03e
#    View of the atrium in the completed Renaissance Center. {http://purl.org/dc/elements/1.1/}title
#    Image of the atrium within the Renaissance Center, looking up at a large concrete structure. Trees, plants, and people can be seen in this picture of a restaurant. {http://purl.org/dc/elements/1.1/}description
#    rencen_03e {http://purl.org/dc/elements/1.1/}identifier
#    1977 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1977 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/3 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_18a
#    View of an unidentified building near the Renaissance Center construction site {http://purl.org/dc/elements/1.1/}title
#    Image of an unidentified building in the vicinity of the Renaissance Center construction site. {http://purl.org/dc/elements/1.1/}description
#    rencen_18a {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/4 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_13e
#    View of the Renaissance Center construction site with earth moving equipment {http://purl.org/dc/elements/1.1/}title
#    Image of large construction equipment at the Renaissance Center construction site.  Drill rigs, bulldozer, cement trunk, and dump truck are all visible within this photograph. {http://purl.org/dc/elements/1.1/}description
#    rencen_13e {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/5 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_28b
#    View of unidentified buildings near the Renaissance Center construction site {http://purl.org/dc/elements/1.1/}title
#    Image of unidentified buildings in the vicinity of the Renaissance Center construction site. {http://purl.org/dc/elements/1.1/}description
#    rencen_28b {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/6 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_09h
#    The Renaissance Center towers with derricks {http://purl.org/dc/elements/1.1/}title
#    Image of the derricks on the Renaissance Center tower on the left side of the photograph.  Three of the four towers are visible in this photograph. {http://purl.org/dc/elements/1.1/}description
#    rencen_09h {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/7 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_15j
#    View of the future site of Hart Plaza and a drill rig, south of the Renaissance Center site {http://purl.org/dc/elements/1.1/}title
#    Image of the area where Hart Plaza was constructed and opened in 1975.  A drill rig is visible in the top left corner of the photograph.  This location is directly south of the Renaissance Center construction site {http://purl.org/dc/elements/1.1/}description
#    rencen_15j {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/8 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_10e
#    View of support beams and construction equipment at the Renaissance Center building site {http://purl.org/dc/elements/1.1/}title
#    Image of early construction of the Renaissance Center.  Derricks and cranes used at the site are visible, along with scaffolding and support beams of the buildings. {http://purl.org/dc/elements/1.1/}description
#    rencen_10e {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/9 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_13i
#    View of construction workers preparing the building site of the Renaissance Center {http://purl.org/dc/elements/1.1/}title
#    Image of the Renaissance Center construction site as workers prepare for future building. {http://purl.org/dc/elements/1.1/}description
#    rencen_13i {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/10 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_12d
#    View of early stages of construction of the Renaissance Center complex of buildings {http://purl.org/dc/elements/1.1/}title
#    Image of the Renaissance Center building site showing early stages of progress.  Old Mariner's Church is seen on the left side of the photograph and the marquee for Ford Auditorium can be seen on the right hand side.  Photograph taken from Jefferson Avenue. {http://purl.org/dc/elements/1.1/}description
#    rencen_12d {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/11 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_19g
#    View of the Lafayette Tool and Die parking lot near the Renaissance Center construction site {http://purl.org/dc/elements/1.1/}title
#    Image of a portion of the employee parking lot of the Lafayette Tool and Die Company which was located at the corner of Woodbridge and St. Aubin Streets.  This location is approximately six blocks northeast of the Renaissance Center building site. {http://purl.org/dc/elements/1.1/}description
#    rencen_19g {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/12 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_24f
#    View of Jefferson Avenue near the Renaissance Center construction site {http://purl.org/dc/elements/1.1/}title
#    Image of Jefferson Avenue, looking southwest toward the Renaissance Center construction site.  The Pasadena Apartment Building, which was built in 1902, is the building in the far right of the photograph. {http://purl.org/dc/elements/1.1/}description
#    rencen_24f {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/13 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_10g
#    View of early progress on construction of the Renaissance Center {http://purl.org/dc/elements/1.1/}title
#    Image of construction of a Renaissance Center tower, in the early stages.  Derricks and a crane are visible, and workers can be seen on the lower portion of the structure. {http://purl.org/dc/elements/1.1/}description
#    rencen_10g {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/14 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_03h
#    View of the atrium in the Renaissance Center {http://purl.org/dc/elements/1.1/}title
#    Image of the atrium within the completed Renaissance Center. Note the trees, plants, and an escalator in the foreground.  Visitors can be seen sitting in a ""pod"" toward the bottom center of the photograph. {http://purl.org/dc/elements/1.1/}description
#    rencen_03h {http://purl.org/dc/elements/1.1/}identifier
#    1977 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1977 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/15 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_26c
#    View of Jefferson Avenue northeast of the Renaissance Center construction site {http://purl.org/dc/elements/1.1/}title
#    Image of the Shorecrest Hotel at 1316 East Jefferson Avenue, which stands approximately two blocks northeast of the Renaissance Center construction site. {http://purl.org/dc/elements/1.1/}description
#    rencen_26c {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/16 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_16g
#    Future location of Hart Plaza near the Renaissance Center construction site {http://purl.org/dc/elements/1.1/}title
#    Image of the foot of Woodward Avenue at Jefferson Avenue, where Hart Plaza was constructed in 1975.  A drill rig can be seen on the left side of the photograph, near the hanging traffic light.  This area is immediately south of the Renaissance Center construction site. {http://purl.org/dc/elements/1.1/}description
#    rencen_16g {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/17 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_25g
#    View of Jefferson Avenue near the Renaissance Center construction site {http://purl.org/dc/elements/1.1/}title
#    Image of Jefferson Avenue, looking southwest toward the Renaissance Center construction site.  Construction derricks can be seen in the distance toward the right side of the photograph.  The Pasadena Apartment Building, which was built in 1902, is seen in the center of the photograph. {http://purl.org/dc/elements/1.1/}description
#    rencen_25g {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/18 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_13j
#    View of construction workers and equipment on the Renaissance Center site {http://purl.org/dc/elements/1.1/}title
#    Image of a worker adjusting a piece of construction equipment at the Renaissance Center site in preparation of building. {http://purl.org/dc/elements/1.1/}description
#    rencen_13j {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/19 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_02f
#    View of the completed Renaissance Center from the Detroit River {http://purl.org/dc/elements/1.1/}title
#    Image of the completed Renaissance Center with the Detroit River in front.  Photo taken from Windsor, Ontario, Canada. {http://purl.org/dc/elements/1.1/}description
#    rencen_02f {http://purl.org/dc/elements/1.1/}identifier
#    1977 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1977 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/20 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_08k
#    View of the top of a Renaissance Center tower with visible construction equipment {http://purl.org/dc/elements/1.1/}title
#    Image of the upper portion of one of the towers of the Renaissance Center.  Derricks can be seen at the top of the building. {http://purl.org/dc/elements/1.1/}description
#    rencen_08k {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/21 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_07m
#    View of the base of the Renaissance Center during construction {http://purl.org/dc/elements/1.1/}title
#    Image of the Renaissance Center construction site with scaffolding and derricks in view.  For perspective, a couple of cement mixer trucks, with orange drums, can be seen at the base, close to the central building. {http://purl.org/dc/elements/1.1/}description
#    rencen_07m {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/22 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_09i
#    Upward view of progress on a Renaissance Center tower {http://purl.org/dc/elements/1.1/}title
#    Image of the Renaissance Center showing the progress of construction of the buildings, with scaffolding and derricks visible. {http://purl.org/dc/elements/1.1/}description
#    rencen_09i {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/23 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_07k
#    Ariel view of the Renaissance Center and the Detroit River {http://purl.org/dc/elements/1.1/}title
#    Image of the progress of the construction of the Renaissance Center.  Old Mariner's Church, with the light green roof, can be seen at the bottom of the photograph.  The Tunnel to Canada grounds can also be seen. {http://purl.org/dc/elements/1.1/}description
#    rencen_07k {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/24 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_25a
#    View of Grand Trunk Railroad train cars in the vicinity of the Renaissance Center {http://purl.org/dc/elements/1.1/}title
#    Image of Grand Trunk Railroad care in the area of the Renaissance Center construction site. {http://purl.org/dc/elements/1.1/}description
#    rencen_25a {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/25 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_16e
#    View of Ford Auditorium in the shadow of a Renaissance Center tower {http://purl.org/dc/elements/1.1/}title
#    Image of a Renaissance Center tower during construction and Ford Auditorium, which was immediately south of the construction site.  This photograph was taken at the corner of Jefferson and Woodward Avenues. {http://purl.org/dc/elements/1.1/}description
#    rencen_16e {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/26 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_02b
#    Future site of the Renaissance Center viewed from Canada {http://purl.org/dc/elements/1.1/}title
#    Image showing future location of the Renaissance Center, before consruction began in 1973.  This picture was taken from the Canadian side of the Detroit River {http://purl.org/dc/elements/1.1/}description
#    rencen_02b {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/27 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_13r
#    View of earth moving equipment at the Renaissance Center site {http://purl.org/dc/elements/1.1/}title
#    Image of the Renaissance Center site with drill rigs in use.  A worker can be seen adjusting equipment in the bottom right corner of the photograph, which was taken on Randolph Street.  Seen in the distance with its brass sculptures is the Old Wayne County Building. {http://purl.org/dc/elements/1.1/}description
#    rencen_13r {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/28 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_05e
#    View of Renaissance Center tower construction and crane {http://purl.org/dc/elements/1.1/}title
#    Image of ongoing construction of one of the four towers.  A large derrick used during the building process can be seen in this photograph. {http://purl.org/dc/elements/1.1/}description
#    rencen_05e {http://purl.org/dc/elements/1.1/}identifier
#    1977 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1977 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/29 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_19m
#    View of an unidentified building near the Renaissance Center construction site {http://purl.org/dc/elements/1.1/}title
#    Image of an unidentified building in the vicinity of the Renaissance Center construction site. {http://purl.org/dc/elements/1.1/}description
#    rencen_19m {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/30 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_20g
#    View of unidentified buildings near the Renaissance Center construction site {http://purl.org/dc/elements/1.1/}title
#    Image of unidentified buildings in the vicinity of the Renaissance Center construction site. {http://purl.org/dc/elements/1.1/}description
#    rencen_20g {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/31 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_29h
#    View of unidentified buildings near the Renaissance Center construction site {http://purl.org/dc/elements/1.1/}title
#    Image of unidentified buildings in the vicinity of the Renaissance Center construction site. {http://purl.org/dc/elements/1.1/}description
#    rencen_29h {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/32 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_15l
#    Ariel view of Ford Auditorium, directly south of the Renaissance Center building site {http://purl.org/dc/elements/1.1/}title
#    Image of Ford Auditorium, which was demolished in 2011.  A small section of a Renaissance Center tower can be seen on the left site of the photograph. {http://purl.org/dc/elements/1.1/}description
#    rencen_15l {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/33 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_06j
#    View from the ground of the Renaissance Center construction progress {http://purl.org/dc/elements/1.1/}title
#    Image of the Renaissance Center showing scaffolding, cranes, and derricks in place during construction. {http://purl.org/dc/elements/1.1/}description
#    rencen_06j {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/34 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_02a
#    Completed Renaissance Center viewed from Canada {http://purl.org/dc/elements/1.1/}title
#    Image showing the Renaissance Center in Detroit and some surrounding buildings after the construction was completed in 1977. This picture was taken from the Canadian side of the Detroit River. {http://purl.org/dc/elements/1.1/}description
#    rencen_02a {http://purl.org/dc/elements/1.1/}identifier
#    1977 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1977 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/35 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_08d
#    View of the upper portions of the Renaissance Center towers during construction {http://purl.org/dc/elements/1.1/}title
#    Image of the Renaissance Center towers and construction equipment used.  Heavy duty cranes, derricks, and scaffolding can be seen in this photograph {http://purl.org/dc/elements/1.1/}description
#    rencen_08d {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/36 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_19f
#    View of an unidentified building near the Renaissance Center construction site {http://purl.org/dc/elements/1.1/}title
#    Image of an unidentified building in the vicinity of the Renaissance Center construction site. {http://purl.org/dc/elements/1.1/}description
#    rencen_19f {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/37 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_05d
#    Close-up view of ongoing construction of the Renaissance Center towers {http://purl.org/dc/elements/1.1/}title
#    Image of the Renaissance Center towers as construction continues, as seen from the ground.  In place are cranes, derricks and scaffolding. {http://purl.org/dc/elements/1.1/}description
#    rencen_05d {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
# ...
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/188 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_20b
#    View of the Northern Engineering Works building near the Renaissance Center construction site {http://purl.org/dc/elements/1.1/}title
#    Image of the Northern Engineering Works building at 210 Chene Street, located approximately eight blocks north of the Renaissance Center construction site.  This photograph was taken from the corner of Dubois and Atwater Streets, looking northeast toward Chene Street. {http://purl.org/dc/elements/1.1/}description
#    rencen_20b {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/189 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_06b
#    Construction of the Renaissance Center towers {http://purl.org/dc/elements/1.1/}title
#    Image of the progress of construction of the Renaissance Center towers.  Note the cement trucks and other equipment at the base of the buildings. {http://purl.org/dc/elements/1.1/}description
#    rencen_06b {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/190 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_20f
#    View of the corner of Atwater and Orleans Streets near the Renaissance Center building site {http://purl.org/dc/elements/1.1/}title
#    Image of the corner of Atwater Street and Orleans Street, which is approximately five blocks northeast of the Renaissance Center construction site. {http://purl.org/dc/elements/1.1/}description
#    rencen_20f {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/191 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_22a
#    View of the Detroit River as seen near the construction site of the Renaissance Center {http://purl.org/dc/elements/1.1/}title
#    Image of the Detroit River with the Ambassador Bridge in the distance.  Cobo Arena, built in 1960 and situated two blocks southwest of the Renaissance Center construction site, is seen on the lower left side of the photograph. {http://purl.org/dc/elements/1.1/}description
#    rencen_22a {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/192 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_11j
#    View of a Renaissance Center tower focused on the upper area during construction {http://purl.org/dc/elements/1.1/}title
#    Image of the upper section of a Renaissance Center tower during construction, with derricks attached. {http://purl.org/dc/elements/1.1/}description
#    rencen_11j {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/193 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_17c
#    View of an unidentified building near the Renaissance Center construction site {http://purl.org/dc/elements/1.1/}title
#    Image of an unidentified building in the vicinity of the Renaissance Center construction site. {http://purl.org/dc/elements/1.1/}description
#    rencen_17c {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/194 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_07h
#    The Renaissance Center during construction and a busy Jefferson Avenue {http://purl.org/dc/elements/1.1/}title
#    Image of Jefferson Avenue in the foreground and the Renaissance Center.  Ford Auditorium is on the right side of the photograph, which was built in 1955 and served as a home to the Detroit Symphony Orchestra (DSO) for more than 33 years.  The building was demolished in 2011. {http://purl.org/dc/elements/1.1/}description
#    rencen_07h {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/195 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_21m
#    View of the corner of Atwater and Chene Streets in the area of the Renaissance Center building site {http://purl.org/dc/elements/1.1/}title
#    Image of the corner of Chene Street and Atwater Street, approximately seven blocks northeast of the Renaissance Center construction site.  This photograph was taken facing northwest and a portion of the Detroit skyline can be seen in the distance on the left side of the photograph. {http://purl.org/dc/elements/1.1/}description
#    rencen_21m {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/196 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_12i
#    Upward view of a Renaissance Center tower as construction progressed {http://purl.org/dc/elements/1.1/}title
#    Image of a tower of the Renaissance Center with derricks secured to the top.  Note the visible directional sign and cyclone fencing which indicates work on lower levels of the structure. {http://purl.org/dc/elements/1.1/}description
#    rencen_12i {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/197 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_14e
#    View of the Ammex duty free shop sign adjacent to the Renaissance Center building site {http://purl.org/dc/elements/1.1/}title
#    Image of the Renaissance Center site taken from Randolph Street.  A drill rig can be seen on the right and Old Mariner's Church is on the left side of the photograph.  The Ammex duty free shop sign indicates the entrance to the Tunnel to Canada, which is next to the building site. {http://purl.org/dc/elements/1.1/}description
#    rencen_14e {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/198 {http://purl.org/dc/elements/1.1/}identifier
# Item rencen_12e
#    Artist's model of the completed Renaissance Center complex {http://purl.org/dc/elements/1.1/}title
#    Image of an architectural model of the Renaissance Center.  Note four large towers with ten shorter towers on either side of the model.  Upon completion, only two shorter towers were built on the northeast side of the site. {http://purl.org/dc/elements/1.1/}description
#    rencen_12e {http://purl.org/dc/elements/1.1/}identifier
#    1973 {http://purl.org/dc/elements/1.1/}date
#    still image {http://purl.org/dc/elements/1.1/}type
#    photographs {http://purl.org/dc/elements/1.1/}format
#    Detroit, Michigan {http://purl.org/dc/elements/1.1/}coverage
#    1970s {http://purl.org/dc/elements/1.1/}coverage
#    Building the Detroit Renaissance Center {http://purl.org/dc/elements/1.1/}relation
#    Users can cite and link to these materials without obtaining permission. Users can also use the materials for non-commercial educational and research purposes in accordance with fair use. For other uses or to obtain high resolution images, please contact the copyright holder. {http://purl.org/dc/elements/1.1/}rights
#    1973 {http://purl.org/dc/elements/1.1/}date
#    http://cdm17409.contentdm.oclc.org/cdm/ref/collection/rencen/id/199 {http://purl.org/dc/elements/1.1/}identifier
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/jajohnst/Desktop/networked-services-labs-2023/xml-exploring-OAIPMH.ipynb Cell 57 line 2
#       <a href='vscode-notebook-cell:/Users/jajohnst/Desktop/networked-services-labs-2023/xml-exploring-OAIPMH.ipynb#Y111sZmlsZQ%3D%3D?line=0'>1</a> for record in records:
# ----> <a href='vscode-notebook-cell:/Users/jajohnst/Desktop/networked-services-labs-2023/xml-exploring-OAIPMH.ipynb#Y111sZmlsZQ%3D%3D?line=1'>2</a>     id = record.find('oai:metadata/oai_dc:dc/dc:identifier', ns).text
#       <a href='vscode-notebook-cell:/Users/jajohnst/Desktop/networked-services-labs-2023/xml-exploring-OAIPMH.ipynb#Y111sZmlsZQ%3D%3D?line=2'>3</a>     print('Item',id)
#       <a href='vscode-notebook-cell:/Users/jajohnst/Desktop/networked-services-labs-2023/xml-exploring-OAIPMH.ipynb#Y111sZmlsZQ%3D%3D?line=3'>4</a>     for dc in record.iterfind('oai:metadata//dc:*', ns):
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# ## More XPath Practice
#
# There aren't a lot of attributes to practice with, but one
# important one that is useful for working with OAI-PMH is the `resumptionToken` value.
# This is a string value that the server shares on paginated results. If you are working to
# get all of the results in a set that is split into multiple pages, you will need it.
#
# The following code builds on the **ListRecords** section above.

# %%
Records = requests.get(Repo_Identity_Info['baseURL'], 
                       params={
                           'verb': 'ListRecords', 
                           'set': 'rencen', 
                           'metadataPrefix': 'oai_dc'
                           })

# %% [markdown]
# Knowing that the record metadata is in the `ListRecords` element, you can just ask for that element directly:

# %%
records = ET.fromstring(Records.text).find('oai:ListRecords', ns)

len(records)
# Out:
# 201

# %% [markdown]
# Note that there appear to be 201 records in this list. But if you look at the collection online, there are 343 items in this set. To get the full list, you will need the resumptionToken.
# That is given as the last subelement of the `ListRecords` element.

# %%
resumptionToken = records[-1].text

print(resumptionToken)
# Out:
# rencen:200:rencen:0000-00-00:9999-99-99:oai_dc

# %% [markdown]
# To get the full list, you can create a looping function that requests from the OAI-PMH endpoint as long as there are records:

# %%
def get_set(Repo_Identity_Info, set, metadata_type, namespaces):
    records = ''
    baseURL = Repo_Identity_Info['baseURL']
    verb = 'ListRecords'
    # first request
    r = requests.get(baseURL, 
                       params={
                           'verb': verb, 
                           'set': set, 
                           'metadataPrefix': metadata_type
                           })
    data = ET.fromstring(r.text)
    for record in data.findall('.//oai:record', namespaces):
        records = records + ET.tostring(record,  'utf-8').decode('utf-8') + '\n'
    # check to see if there are more requests needed
    try:
        resumptionToken = data.find('.//oai:resumptionToken', namespaces)
    except:
        resumptionToken = None
    # if so, then make more requests
    if resumptionToken:
        r = requests.get(baseURL, 
                         params={
                             'verb': verb,
                             'set': set,
                             'metadataPrefix': metadata_type,
                             'resumptionToken': resumptionToken
                         })
        data = ET.fromstring(r.text)
        for record in data.findall('.//oai:record', namespaces): 
            records = records + ET.tostring(record, 'utf-8').decode('utf-8') + '\n'
    return records

# %%
record_list = get_set(Repo_Identity_Info, 'rencen', 'oai_dc', namespaces=ns)

# %%
with open('OAI-records-list.xml', 'w', encoding='utf-8') as f:
    f.write(record_list)
    print('wrote file')
# Out:
# wrote file

# %%
#TODO the above creates an invalid XML document with multiple primary 
#namespace declarations - the creation of the individual objects requires more work
#see below does not work

# %%
metadata = ET.fromstring(record_list)

for record in metadata:
    print(record.tag)
# Out:
# Traceback (most recent call last):
#
#   File ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3526 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[83], line 1
#     metadata = ET.fromstring(record_list)
#
#   File ~/opt/anaconda3/lib/python3.9/xml/etree/ElementTree.py:1342 in XML
#     parser.feed(text)
#
#   File <string>
# ParseError: junk after document element: line 18, column 0

# %% [markdown]
# OAI-PMH records tend not to have many attributes, so there are not a whole lot of XPath
# things to practice. For more practice with XPath, see the notebook `xml-xpath-examples-EAD.ipynb` in this repo.
